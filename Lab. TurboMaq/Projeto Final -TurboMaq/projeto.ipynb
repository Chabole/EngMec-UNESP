# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import turbina as tb

pd.options.display.float_format = '{:.3f}'.format

# %%
H = 10  # m
Q = 100  # m^3/s

df=tb.modelo_turbina(10, 100)[1]
#print(df.to_latex(index=1))

# %%
tb.modelo_turbina(10, 100)[0]
# Out:
#                                              0
# Salto de energia                        98.100
# Velocidade específica                  675.390
# Rotação da turbina                       2.105
# Número de polos                         54.000
# Coeficiente de Thoma                     0.934
# Altura máxima de sucção                  1.936
# Potência disponível                9780570.000
# Rendimento total                         0.900
# Rendimento mecânico                      0.970
# Rendimento volumétrico                   0.990
# Rendimento hidráulico                    0.937
# Potência de eixo                   9166419.869
# Coeficiente de dependete da tensão      11.000
# Diâmetro do eixo                        17.962
# Relação cúbica                           0.377
# Coeficiente de veloc. meridiana          0.578
# Velocidade de meridiana                  8.095
# Diâmetro externo do rotor                4.261
# Diâmetro interno do rotor                1.608

# %%
tb.modelo_turbina(10, 100)[1]
# Out:
#                                            1
# Diâmetro                               2.935
# Variação da componente de giro        91.940
# Velocidade tangencial                 19.410
# Variação da velocidade entra/saida     4.737
# Velocidade da corrente não perturbada 18.867
# Ângulo de construção                  25.409
# Número de pás                          3.000
# Passo de cada pá                       3.073
# Comprimento da corda externo           0.909
# Comprimento da corda                   1.081
# Comprimento dos perfis                 3.322
# Coeficiente de sustentação             0.482
# Relação para escolha do perfil         0.083
# Fator de engrosamento                  1.000
# Ângulo de deslizamento                 0.971
# Rendimento do perfil                   0.960
# Ângulo de ataque do perfil             5.667
# Ângulo de inclinação das pás          19.742
